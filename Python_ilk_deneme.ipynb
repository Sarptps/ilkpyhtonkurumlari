# %% [markdown]
# Python programlama dilinde print komutu ekrandan kulanıcıya bilgi veren bir koddur                                                                                                                                                           06.08.2024-Veri Yapıları ve Algoritmalar dersi ilk kodlama çıktısı            İGÜ İSTKA SİBER AKADEMİ MERKEZİ-

# %%
 print("Merhaba,İGÜ - İSTKA!") # print ekrana cıktı veren bır koddur.
# Out:
# Merhaba,İGÜ - İSTKA!

# %%
import sys # import python proglamlama dilinde kütüphane eklemeye yarayan bir kod blogudur
print (sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERİYAPILARİ_ISTKA')
! pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur
# Out:
# /content/drive/My Drive/VERİYAPILARİ_ISTKA
